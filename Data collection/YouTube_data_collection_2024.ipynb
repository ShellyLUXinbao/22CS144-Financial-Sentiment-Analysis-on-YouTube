# %% [markdown]
# Step 1: A list of 15 YouTube news channels is mannually created

# %%
import datetime
import pandas as pd
import re

# %%
channels = [
    {'channel_name': 'CNBC Television',
     'channel_id': 'UCrp_UI8XtuYfpiqluWLD7Lw'},
    {'channel_name': 'Yahoo Finance',
     'channel_id': 'UCEAZeUIeJs0IjQiqTCdVSIg'},
    {'channel_name': 'Bloomberg Television',
     'channel_id': 'UCIALMKvObZNtJ6AmdCLP7Lg'},
    {'channel_name': 'Financial Times',
     'channel_id': 'UCoUxsWakJucWg46KW5RsvPw'},
    {'channel_name': 'The Wall Street Journal',
     'channel_id': 'UCK7tptUDHh-RYDsdxO1-5QQ'},
    {'channel_name': 'Reuters',
     'channel_id': 'UChqUTb7kYRX8-EiaN3XFrSQ'},
    {'channel_name': 'The New York Times',
     'channel_id': 'UCqnbDFdCpuN8CMEg0VuEBqA'},
    {'channel_name': 'The Guardian',
     'channel_id': 'UCHpw8xwDNhU9gdohEcJu4aA'},
    {'channel_name': 'Fox News',
     'channel_id': 'UCXIJgqnII2ZOINSWNOGFThA'},
    {'channel_name': 'CNN',
     'channel_id': 'UCupvZG-5ko_eiXAupbDfxWw'},
    {'channel_name': 'NBC News',
     'channel_id': 'UCeY0bbntWzzVIaj2z3QigXg'},
    {'channel_name': 'ABC News',
     'channel_id': 'UCBi2mrWuNuyYy4gbM6fU18Q'},
    {'channel_name': 'CBS News',
     'channel_id': 'UC8p1vwvWtl6T73JiExfWs1g'},
    {'channel_name': 'BBC News',
     'channel_id': 'UC16niRr50-MSBwiO3YDb3RA'},
    {'channel_name': 'The Economist',
     'channel_id': 'UC0p5jTq6Xx_DosDFxVXnWaQ'}
]

# %% [markdown]
# Step 2: Within each channel, search videos that are stock-related

# %%
# YouTube Data API
from googleapiclient.discovery import build
api_key = 'AIzaSyAJ0iBGJ3KGzqa8kGy1C5XXfRN15eAlKuA'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_video_ids(query, channel_id, published_after, published_before):
  videos = []
  next_page_token = None
  while True:
      video_request = youtube.search().list(
          q=query,
          part="id",
          channelId=channel_id,
          maxResults=50,
          pageToken=next_page_token,
          publishedAfter=published_after,
          publishedBefore=published_before,
          type="video",
          videoDefinition="high",
          )
      video_response = video_request.execute()
      videos += video_response["items"]
      next_page_token = video_response.get("nextPageToken")
      if not next_page_token:
          break
  video_ids = [video["id"].get("videoId") for video in videos]
  return video_ids

channel_ids = [channel['channel_id'] for channel in channels]
query = "stock"
published_after = '2024-02-25T00:00:00Z'
published_before = '2024-03-11T00:00:00Z'

video_ids = []
for cid in channel_ids:
  current_video_ids = get_video_ids(query, cid, published_after, published_before)
  video_ids += current_video_ids

# %%
video_ids
# Out:
# ['YEoJq_PcOgc',
#  'Hp6IRjNJuI4',
#  'GQK4bCZHudM',
#  'BOm0zNiaNjg',
#  'Z0D_FwSF5z0',
#  'WxpT73CzQGM',
#  'XTCiSQhcIvk',
#  'cTncTPylZQ8',
#  '6Gn_g2pQ0LE',
#  '-8QJEmi8TlI',
#  'KfxGBn3mqCE',
#  '7WQfx5uTTJo',
#  'TQTv0tVTFeU',
#  'qAITe2Hn8Hc',
#  '25RoHnzpYhg',
#  'G573i2zmNkk',
#  'NyoIuiFkWVw',
#  'fIw6XBGxfhw',
#  '1CfJD6rIfEI',
#  'DbzX64TystQ',
#  '4w32DQ_a4qI',
#  'WRcMVN7uuQY',
#  'ftSzI6MP7mo',
#  'hco3AOTj24o',
#  '2TiXOHGK9EQ',
#  '5csg3rKulds',
#  '6OnjUyzSPKo',
#  'EUcIbKO4M5A',
#  '5CHG7NARcn0',
#  'WZ1f3jdb-To',
#  'NvSK3iHdXcM',
#  '9TwqOGtPEYc',
#  'R3FmJr05wNs',
#  '8DynmkGeSYY',
#  '0WQSSp_wYrA',
#  'o3Bo6TscisM',
#  'PuQx9vs9Aek',
#  'UO7utWSxZDg',
#  'M7Nj9Kf13bk',
#  'tixpZyKhQok',
#  'SWJiz-QKSF8',
#  'kM2ud4ugwAY',
#  'X6iCYjkVLPU',
#  'fg8ryusNedY',
#  'dAMRdOlfJPo',
#  'dxzlpaCVdIo',
#  'nQ1Xl3mulo0',
#  'P89swLwXosU',
#  'eviXkRXJ7jE',
#  '3dg0d1yT7iY',
#  'eviXkRXJ7jE',
#  '3dg0d1yT7iY',
#  '2pqwuJ7gZBk',
#  'gbTEmNWLfvE',
#  '_VBMkDiGCq8',
#  'zw_lqqw7Ob4',
#  'ybPLOT0wgBQ',
#  'D92lE_X4DlQ',
#  'K0yGRDUu0G0',
#  'MqXL5MQ-0WI',
#  'PE8e2nZ5C6Q',
#  'Ne_WoJdOZT0',
#  'J_-UmGcwOh4',
#  'jwwa9oON1EQ',
#  'EpEgo2I410U',
#  'Ug9sxemj5q4',
#  '1klmATNNtXA',
#  'tuf38NWPhwQ',
#  'hgCELgyyCHE',
#  'Bm0inOkyYxE',
#  '5Ns1eij9gqk',
#  'wDWaTwiBoVw',
#  '_zNulk5FQWw',
#  'UpzXHkliqZA',
#  'IAEko3YgzSY',
#  '6Z-uAccME04',
#  'YHyh9DYOmDg',
#  'L6dpSXOnjbU',
#  'dh8KiZrPj34',
#  'ZkwVu-1r1Tk',
#  'iJ00fe_Yy28',
#  'gmySXRM94i0',
#  'i2iAmSfPo58',
#  'zoQIT4Vn8H4',
#  'PHwIQOYo6i4',
#  'Jrc0zurcwVE',
#  'nP4gYJ31omI',
#  '_4OEQlpVcIc',
#  'smToa0_wXxo',
#  'lL1EC8CZvk4',
#  '_JVgNT_VsHc',
#  'gzBon0qM7Ag',
#  'd27ZNyvyFpE',
#  'VLDSo0_3_H4',
#  'vX2WAYyV-L0',
#  '4l60ncIz7co',
#  'AojjU8Lkc1A',
#  'HeqbnjuZQIk',
#  'vQSZbyDVPpo',
#  'xlzeH5SsZrQ',
#  'jlWtm3g1S7E',
#  '-mbZ1YK5OcA',
#  'ICE6qqDCFsM',
#  'LacPFD2ZDEs',
#  'kKILXnL8D9M',
#  'Z1FhE0Jfq8w',
#  'l7PJ_vJHA7Y',
#  'WsTCJokwEGA',
#  't6C0yo9FuAQ',
#  '-CSjFtE-Bag',
#  '6KDk9orJ5Y0',
#  'DOXhPJ0B5aI',
#  'QYcnW8rNfx4',
#  'VtB0h6bCiGY',
#  '3pSfXdw1WrM',
#  'OK_rF301k3Q',
#  '__dYMQ9Yef8',
#  'HEvQ7C8ZfDA',
#  'dHUkvpUaQ1Y',
#  '7gHyK8yLEA4',
#  'UnFDGS3EAcc',
#  'ZZw_Gy50bio',
#  'DoZVR4K0-5A',
#  'Enp6N7J5O1M',
#  '2Akc7PRf0wY',
#  'mY8xkGciYeU',
#  '1FEFvKnk2vA',
#  'Vqc7qktK6g4',
#  'Lx5wJQIeDek',
#  'tP6TplUkxuA',
#  '5BGiGuDbYmM',
#  'YYrdfvDkgi0',
#  'F02qPg_9O0g',
#  'rUNj0U8XwWk',
#  '9fD80bY9ouw',
#  'xYVImuGQjSQ',
#  'gjZbw65Abfo',
#  'JlEIkgA-pHQ',
#  'wTlWoSlifz0',
#  'GcGikW25RK4',
#  'hFfDJ63UCcY',
#  'nxZWfoYfYmg',
#  'SQQ-AhLHhIg',
#  'm03yKAHLwZE',
#  '4Mq7G_6nles',
#  'v7_DLh-1RIU',
#  'M1d1RmuVSwE',
#  '2PPlAwg9Od8',
#  'vGraFfl3GnM',
#  'lmh_77tSob4',
#  'aFzKqm7P5-k',
#  'Z0JwIm2DTEE',
#  'oL8ahJJQdYc',
#  'f_dHRskO9rs',
#  '1W0L4hFauKU',
#  'zOIwCYBY3xs',
#  'Rd7pbRyQPws',
#  'F_dt5PlxQB8',
#  'Tl5zTduseCQ',
#  '9EExCEIHrpY',
#  '1cY4qu65xQA',
#  'e_2dzNhLy3w',
#  'hHV5E3NiDbg',
#  'hV3N-nuxO1s',
#  'IwKb3Ul8twg',
#  '4cvFL8G1LUg',
#  '0k-WNjugGCg',
#  'eoVcDsei054',
#  '1KvwWR33ISE',
#  'AJZINady-vE',
#  'XsH1eCaAXus',
#  '4NhDcypSatM',
#  'STH6OK8ojys',
#  'STS7Am4gl30',
#  'OYxzpItDEwg',
#  'NFgzSsg36xg',
#  'PgUoqtqDs1E',
#  'JIcKc3NaRn4',
#  '1n5lB-Y40fs',
#  'ppaJrnvRREg',
#  '-asrv2hwEGk',
#  'z3gOJD_t3Co',
#  'a68LbKTUwL8',
#  '0xQaw2oQSfw',
#  'oyFe76HE7sQ',
#  'lmfsA07YWW8',
#  'jeUEOmBokQY',
#  '7Y1-WK4_ejk',
#  'rA71d0Cbsys',
#  'MDgMOslZ2a4',
#  '49Fks3k9xd8',
#  'PXlVfWPlV2M',
#  'y3A_7jeiIEg',
#  'SwhoDdrRmCo',
#  'puMuXWKl6sA',
#  '7fA6JFaouUk',
#  '5Ho5S4n-asI',
#  'van_fgoJWJ0',
#  'pHmIoQBjUJw',
#  'UCRVljwAzmQ',
#  '3A69nYR3fyI',
#  '7c4i2LL6XcQ',
#  'S0_g8vdKk6A',
#  'roVJ0dcONNw',
#  'Et8c_2ykWG4',
#  'Droj7JKC04o',
#  'oEj3j3SfNNk',
#  '7BRP1b5c4RE',
#  'HB3nxZD7VDk',
#  'oA6ECZrEAjw',
#  '5reltcZ8XI0',
#  'IB3Dcai0VmU',
#  'eZA5EVy3fRs',
#  'CJRMh5ugXmI',
#  'isbSDgNGwYs',
#  'a80ATMQkWtc',
#  'QzKUFebexIM',
#  'EUHNEsJPWZk',
#  'R1PDOo7DKMc',
#  'RTvwO21tYsQ',
#  'XBvfuLrB46w',
#  'd5xBQN7OrLs',
#  '3pjlHhiJUcI',
#  'lZ8E_5Rrdvc',
#  't0zOeuDYUPw',
#  '62-tvBGb59I',
#  '7_hlKVMZgiA',
#  'sBUc8uMr3lc',
#  'c5SXdemEIdM',
#  'Jfs7DyEMBEs',
#  '9JI8HQjqdUg',
#  'OibuqEJqh84',
#  'iYLc1ABdy-c',
#  'uSCslPbcKLk',
#  'yfZS25NF14U',
#  'vNkb4_VCCQk',
#  'loESyNHMNeA',
#  'J7FRza7YAu8',
#  'Ahrlte6-PKM',
#  'sVuTOwfCLgQ',
#  'lwZmQUS0HSI',
#  'pFsP1cvJQvs',
#  'nD6DfOiF9m0',
#  '8UwYxS9wffc',
#  'KGcoOQ2-ah8',
#  'wuMSBlWIRQw',
#  'V55ZMNPOujM',
#  '3yT-838RSj0',
#  'QRRMFqNi2_k',
#  'x7259c6Hqvk',
#  'AG7yXT3Dg6A',
#  'ptzjz4bsdKM',
#  'h8r0H0NI89Q',
#  '7neLcr43mlM',
#  'mWDXyyA8kuA',
#  'RvZ1s2E1gOQ',
#  'wsjotJzotcs',
#  'PBDxalEhQvI',
#  '8Ba6l8mUC7A',
#  '-ClEa_WH4js',
#  'RiNnsLnah-U',
#  'Agc_vJu-Xc0',
#  'xyjirAaItgA',
#  '3IAlqgXZGdc',
#  'F3aLkb5GELY',
#  'sxG5THYWvL4',
#  'jtob3q8jLr4',
#  'lk27mY-VpVY',
#  'P4XhdhFFjN8',
#  'lu954DCdoB4',
#  '_0x3_8IynU4',
#  'taWTzjmWmbs',
#  'fmWyEMVoBYY',
#  'oxVysDOZpHw',
#  'N3Cy2w2c4Yk',
#  'TcSmxh0_fdA',
#  '4dRxEgKe2Rg',
#  'RevOQOJhJ4U',
#  'qh3tI49EiXQ',
#  'VDL7pliv4qg',
#  'hlsEANxUnts',
#  'waJlTNRAook',
#  'cLWT3iaMDHM',
#  'EcOnv_iVwAs',
#  'rx34Ldm923c',
#  'artYDpCOxas',
#  'aArZf2Mvdk8',
#  'eDDvGFLo-F0',
#  'L91ak3jbxCQ',
#  'rytrswAfB60',
#  '8ebFOjhZ4KU',
#  'gNiZluuE274',
#  '78U3w4LZQzM',
#  '5WGrqfJJA20',
#  'nLV_XP3m_9w',
#  '9Ag8t-935zg',
#  '3kEcPNAGvB0',
#  'pbWlgOrOKmQ',
#  'KAbz0dy6dEg',
#  'UbHadsvchtM',
#  'Kle52l8fKJI',
#  'hOgzmVrc8HM',
#  'VmmrLxfdHxk',
#  'aXhexX7G6JY',
#  'KiQkOhBkDPk',
#  'vDPH9zA0uM4',
#  'cY8r_3GCGUw',
#  '_eylwxTnxuk',
#  'eTWcK2zeNTY',
#  'zMRfu8EvY7w',
#  'TzXSK-2KZTg',
#  '24T1stMNoLE',
#  'smxPPg7ZWKc',
#  'pDLuSA28cLQ',
#  'NQgRWdyYZLg',
#  '2foEymwFJQ8',
#  'zfB6yaIO9yo',
#  '-Sne6cup9MQ',
#  'cj1yLP9Z_uU',
#  '051eQLCsfEs',
#  'PrVun8br9mY',
#  'nKLs8tCE2Sk',
#  'XP4Ri8QcB10',
#  'HSCfgduwi2c',
#  'tVizD7_97fg',
#  'GBXdm_MCu5s',
#  'zk22E8z8qm8',
#  'zMfjn6SmcM0',
#  'OhaIusKCLDs',
#  'Soo2TetXOzk',
#  '_V1YC1rC6_I',
#  'D5Qkvn4GYiQ',
#  'TuDvZry6bvo',
#  'c4rtCYKow0M',
#  '2MWTMQfavYU',
#  'TQfJaHM_ceI',
#  'JDRZf98bC2E',
#  'VP8SJE--U_g',
#  'C7-Hpgu9Ezo',
#  '-6PBWdY2YwE',
#  'xvlpIF9NPys',
#  '-6Fznv7ufH8',
#  'UOQoT-P14pE',
#  'lKnW9HydN2s',
#  'FxSkJkTPbgI',
#  'XbJ0mq0X1I4',
#  'j2WRMtq3T-o',
#  'xsE0TwO7eD8',
#  'gYeVQ126zDw',
#  'fD8T4I0Fdfw',
#  'TsPcptwElQc',
#  'ZD3D9fqKUa8',
#  'k2wSDQu9M3A',
#  'ljqyIAnnryM',
#  'KYSRTA0mhEk',
#  'aOZNX90kqB8',
#  'PJJz7Wrza3c',
#  '1fT0xrCJlIc',
#  'tL-ecCTFwfI',
#  'vy6H5XyV7bQ',
#  '6joVbGA2nKw',
#  'yLoTop-Emak',
#  'Px5ZB6JuLFw',
#  'bbwO7mH8yYs',
#  'oVOrOHTRx58',
#  't23tcbI3a60',
#  '1jksH-B-M80',
#  'RXThXwOvkY0',
#  'XlsPmGYy7TU',
#  'uoTKkw9ic7c',
#  '834p9evBR48',
#  'WGksFVVuIxA',
#  'Ud23h0YyRGk',
#  'D-JzuemzJVw',
#  'KIcHtnvqVtM',
#  '4yeCqUUD8b4',
#  '2BQbYJGCs6w',
#  'kPS-wGgX3Ao',
#  'cbC_GYYN0pc',
#  'Vs3rC_QPfxU',
#  'AsKgZVuTef8',
#  'aAb-Di3AJvc',
#  'TgI8pMiJ-rI',
#  'i5O5stMujus',
#  'NA0jyQoqiMI',
#  '_Nqo38wSZpg',
#  'DpT5W2TgLuQ',
#  'mdEdOk3Tv8A',
#  '_wQcFE5pagw',
#  '03WDcC1B1kw',
#  'IHbgR_pxY4k',
#  'dTVK2QLMGAU',
#  '9BKazShYFOo',
#  'KzQgqTHHMNw',
#  'cAtIUNpUtLM',
#  'POxLq7b49i8',
#  'aGear5eSRoY',
#  'bTFbkGn5ugA',
#  'pIgrmWs-q3U',
#  'M5LlBjuBAkU',
#  'gU947h7RYbY',
#  '1CAi31Z-6fw',
#  'QxnHJSFSoaI',
#  'GUbLE78v91c',
#  '4beyvCCxSc4',
#  'lHBQJden5kM',
#  'J_Nijmbcuh8',
#  'YLo-6bJ3njs',
#  '29PKjKGuEQY',
#  '-rfx0mkjDyM',
#  'T1P3LyssWvA',
#  '-zzZk4ll1t8',
#  'wo1FfVuBark',
#  'zH_lSOXNjFw',
#  '78z1jEj-2Io',
#  'yxzqq30rwlg',
#  '5t6MQCD9_eY',
#  'Yl-3rMn-p_g',
#  'sZ2CkOI01K0',
#  'JBRUTBtkouI',
#  'VbziVP02aeU',
#  'RXThXwOvkY0',
#  'ZZbVGKzd0Cs',
#  '6f5qumfvc9Q',
#  'TSCt6lbcMDg',
#  'dd-KSYNcjQs',
#  'nyFM1URefro',
#  'tZhbRwuiJlg',
#  'phVv_FfFufU',
#  'r0kvHbE_KmE',
#  'wfILUwKjnKI',
#  'Vn7P0XUKu-k',
#  'Hz7hjbJdipY',
#  '6WRNQL1Oj1k',
#  'sPxiQVsaIz4',
#  'h1cpPae8AIA',
#  'ktpyFHMC3ts',
#  'c_uA3BGb4aU',
#  'TgI8pMiJ-rI',
#  'k5AvO39RtXc',
#  'IHbgR_pxY4k',
#  'GqYKj_DESfo',
#  'M5LlBjuBAkU',
#  'YLo-6bJ3njs',
#  'vAA-XZtSkRc',
#  'Fc8a2VDssds',
#  'MJ8fo6TKIS4',
#  'cwG022pJa5k',
#  'SAge3xF2nJs',
#  'RPeplvGv8PI',
#  'BQMEDU7bjUQ',
#  'yhQN5FZ0ANI',
#  '4UDZOfEH17s',
#  '2-mPKmEAhCQ',
#  'meTcM6EvX8E',
#  'R23IIgnc1j8',
#  'kx_2VNQgW1c',
#  'Fg0q0m64RFc',
#  'haOoMAqxds8',
#  '8BE2TDFFQ1Q',
#  '4UDZOfEH17s',
#  '2-mPKmEAhCQ',
#  'meTcM6EvX8E',
#  'R23IIgnc1j8',
#  'EHWHbYKnz8Y',
#  'VzWYhiUfdHc',
#  'Fg0q0m64RFc',
#  'haOoMAqxds8',
#  '8BE2TDFFQ1Q',
#  'M39GUOZdCWU',
#  'm2luB-IXhTI',
#  'OG-rrRstVm8',
#  'Lz6YhGsHqcA',
#  'kPGPKKd1-MY',
#  '_Bb63yuwTS4',
#  'tA4Oh-f8U9I',
#  'nEUbUyondt0',
#  '1r1eB0uJM_c',
#  'qwaqYVQXF8E',
#  'Xf-wFSy22nE',
#  'rO8lwRfAP0I',
#  'Yf0eBfN-k-s',
#  'jycefS6h2Js',
#  '2SB3LH3hk6M',
#  'zlgno8e-CiM',
#  '60Lm4oKyu-E',
#  'LafD4t1TfZM',
#  'hhWhyPf5UMY',
#  '9LorC3MEbLc',
#  '14-t7_Mg6WY',
#  'kEIPb2zU5F0',
#  'Tsy3INh79xM',
#  'N6gqn64_AOc',
#  'L2f9HakGwGk',
#  'B07Pr9OvQnI',
#  'TEpq5xKww20',
#  '-eXiR3QJhiE',
#  'h7X2nBuDGUc',
#  '-MCah-kg4fA',
#  'GTkmiZVDa-Q',
#  'fN3rWdkznsk',
#  'uT78WvnLgAU',
#  'fvb8uU51r3c',
#  'rRZOoVYQWRg',
#  'pf_v9Skiy-U',
#  '12f_TT3fjgE',
#  '5FmeY6gAwXU',
#  'E-rjp2TQDhw',
#  'Ss46qH5KkjE',
#  'BvH743ouClM',
#  'dTl1HaejwpA',
#  'uSRQDMHqxIY',
#  'p7yMUlgq67U',
#  'c_-3YTRfZWA',
#  'k7pvQ4hDMJM',
#  'kGwqaeEJoxg',
#  '6F0VzpNRUss',
#  'hlZjr4Rny1A',
#  'r_G42IrGsrA',
#  'IB4LIwgcRc0',
#  'UNtrS5omwzE',
#  'pnO7e16QveA',
#  '-bNfUt5kLFE',
#  't-FTpYJ6JtY',
#  'msF6zGuwdn0',
#  'wBeCOwyUMb8',
#  'Fu2avJSFPAQ',
#  '6e7Fcpv3grM',
#  'fcGl58gCjwg',
#  '5IwUSAd4qnY',
#  'iDLrsOeFfsU',
#  'dtXY--HVvEo',
#  'TGFNjwc2-CI',
#  'zfUkooleyEo',
#  'KE6rfkyuySQ',
#  'SiIlquPwyh4',
#  'Ok9q5ExAhiI',
#  'xH1aO_OsV8s',
#  'HjGryIH_8CE',
#  '4M11hLPnNo8',
#  'obfZvM44Y-w',
#  'dyqa1tfsA9I',
#  'amDiL8-6W8Q',
#  'kY1W4e8-kso',
#  'lg0UgDJd3Zs',
#  'l-qChF7WAb8',
#  'dJzQVRNFs-c',
#  'FC5vVPrIK1s',
#  'MF7f9swcPAY',
#  'cfN1Wfep_bE',
#  'vvcO5yenp1k',
#  'r_jb2J_fbLI',
#  'JjsoSx5lZAk',
#  'trmdZ7HiFZk',
#  'hxWely5is5U',
#  'DKep7QEu6-o',
#  'sL6tynrSZ60',
#  'E_ugCq6xQIk',
#  'dSM_rA37RWk',
#  'KOK9K-txs-w',
#  'LDV2VBqopoQ',
#  'igzznRTxxT8',
#  'mjDtvcq5hr0',
#  'b--6hZw5WYg',
#  'MSu_ticYInc',
#  '0IxhJMeevFU',
#  'xy7ICmAOsxQ',
#  'fc77lPyWfWE',
#  'J_cx3Q7C_Oc',
#  'ldnhLmM4d2c',
#  '_HR20pgrUwQ',
#  '6KnEaGBu0Ws',
#  'dT6yRDhpU_k',
#  'TLaMMDYWDSY',
#  'QE5JuV6kD3U',
#  'MbCFFoMdRHU',
#  'T0Z7o7HdhpY',
#  'uLy-zP1bPbM',
#  'ZH3Pkty7ThA',
#  '4KUxsiDIo6U',
#  'gZdi5V4WX0I',
#  '_sMl-yWn34E',
#  'IFnbuP2HsnU',
#  '_nq8BrERi8k',
#  'lugBMFvYf3k',
#  '9CeCrtwBlmg',
#  'I02m0K-H8u0',
#  'R8gFGEIe_q0',
#  'OWysoTXCB4M',
#  'HnTvWMOlVtQ',
#  '4Y2PNJw4uhk',
#  'dHRraWxoIIs',
#  'izJQZLPXrt0',
#  'o_tWPrIRNNg',
#  'mrHmLEkTMjc',
#  'JeuCw3KswpY',
#  'YPKMpJwaBiQ',
#  'wOhT8gYpNoM',
#  'bJPuZ3bXJo4',
#  '1xizOd-3aRg',
#  'CRiFgzLLA4s',
#  'RhPvmYHaZAI',
#  '7xomzfXfjUM',
#  'wPUz1ubAiB8',
#  'eoe_qB2wjEw',
#  'SmC3LtmRDng',
#  'L9ZS0MTi5EY',
#  'kGxxXMlMHkM',
#  'Z7lvTsV5nIc',
#  'rvGTFdEp0G8',
#  'M9kKQxeatXA',
#  'ODgPT4pMrt4',
#  'pNgaZ72WJK0',
#  'hHBdbXXS-aA',
#  'I2Sa7CTItmU',
#  't3HGc6P5p3E',
#  'GjauQsIR_jA',
#  'r1vnpHnmT88',
#  'pY3jv41kqis',
#  '1YFNtmuPwJU',
#  '9xxn9JBOpm4',
#  'RazOMPvfOTo',
#  'alBfKE8eUGA',
#  '4E1c1dcOjGo',
#  'eB6r6VThIAA',
#  'ltudvS8tZxQ',
#  'VDw6Z9c6O3U',
#  'eJVnOpnmDkg',
#  'A5ott-8a3FU',
#  'KXervpK-iFI',
#  'lRcol-bowRI',
#  'r4eDslI7PxM',
#  '6fsbc6Zf25U',
#  'q3N5qORkhCs',
#  'asleU_BSw28',
#  'gYks2tfvsLE',
#  'qhix4gvMjJw',
#  'BBZKtcxiwDE',
#  'i949rt09_PY',
#  'SqtIXkGER10',
#  'B-fLvLnF5GY',
#  '94bRuNyCWVs',
#  'Uyv6BPk6iqQ',
#  '7ed_PlyRmIo',
#  'jBl667iFKB8',
#  'vj4v0nJIA_g',
#  'Q_HvQX7dJ1U',
#  'mIsJTlLI5oM',
#  'xghbzFZIJWg',
#  'qdeJum1SVA8',
#  '9kYm7nBHylU',
#  'AJlsWjNL8E4',
#  'ehQbUb_nG_I',
#  '-84w4Rtm8HU',
#  'bNAZeizA-OI',
#  'HzAgEnFA5IU',
#  'LSVD_B7lfwU',
#  'e1jdKy1MIWA',
#  'e502p5U8FKA',
#  '6YNo14J0i3g',
#  'FHKLJ2uvdLY',
#  'AwHAEYAzEfs',
#  '7dJ5eU68bgo',
#  'cla1nVFh3PY',
#  'LpSK3TxZhpU',
#  '2dBrxQJ2lgc',
#  'Zi9iFelB4Us',
#  '2nOaeA7X7dY',
#  'sgqQIqg1KCE',
#  'boGp08uAJY4',
#  'XS8RrjHu-T8',
#  '85onTGR8g-0',
#  'rc1MqLtEtdk',
#  '-D7EKS7tB6A',
#  'NrSRr4gB790',
#  'nP-9bwpnHr4',
#  'EZU0nbHQJn8',
#  '-DJh2FIEy1Q',
#  '6gOczqKJtyw',
#  'uFHEFoIf9I8',
#  'uSHG5qR7Qjg',
#  'lVVo32xa-u4',
#  '4ZhINw_0dJc',
#  '5tEzp2L7nbU',
#  'LpNF8quXBAM',
#  'eaV5N0JwM38',
#  '6f7JQNwEALA',
#  'ay15MIOJoo4',
#  '8vdgO0r1NMQ',
#  '-wBUpFLoId8',
#  'w2y3Fsm-ITs',
#  'GUan2CECeKI',
#  'GD6F-77TkIg',
#  'zhNRmaCEz-0',
#  'yfSteMs4dfU',
#  '6f4G6gzrFog',
#  'rQilogMwOQY',
#  '5TPhFHaUyAg',
#  'iiMhQWDi1mw',
#  'F4eI5RShwLs',
#  'eNsoX6myOC0',
#  'tHq5tNpxMvk',
#  '0V8o5_NKv34',
#  'xtNfJf5aVhk',
#  'a4pKVkW3cgU',
#  'A0cwtdJTZfI',
#  'ZQQDyHrM0rs',
#  'bzogsjYqJjc',
#  'LZakyvBJQHU',
#  'qOqeaQfPQoA',
#  'ZsycKYI5zQQ',
#  'SxgXFqxsVPE',
#  'Z2W5A8BUBAo',
#  'aSF6nMTm4Ck',
#  'RcEu8lNJC2U',
#  'CEVWJO3zlK4',
#  'UXEbnmtIej0',
#  'pL44YNOcBcs',
#  'd3Nf8AKFoEU',
#  'Owmy5Vu3BnA',
#  'sYoEnijUG0s',
#  'NTzcQt7lPVQ',
#  'Z2UEMXHTiNw',
#  'ruNNQtsBsyM',
#  'M9MNDsQFzz8',
#  '_r9IDmph2d0',
#  'Z4ggR16Stu4',
#  'z_Bic4iW55E',
#  'HMc43jQDxhI',
#  'lHUj1DsJ5Cw',
#  'jwFDN5zPb4o',
#  '9NtvUDJskzw',
#  'UnR3bap7YEA',
#  'KrkxWOcz2II',
#  'y9YWvcZrxGQ',
#  'CfPPXwY2ImI',
#  'nKfbJGqlvPw',
#  'xXQl52deZ4w',
#  'r0PAaJ4o8Bw',
#  'SoG-0_mb4l4',
#  'adACdtLOlVc',
#  'ezCKGT7XPQo',
#  'mtwFc80R_B8',
#  'vxqcnGLTfI8',
#  'JecAtA-SSRM',
#  '6gvL59jUUNw',
#  '9CRR4BB3KNU',
#  'gG1dcpi8stg',
#  '0RtfMEWDDlk',
#  'zMGBwYrX1ZE',
#  'k4Et5yd_4qQ',
#  'KCbhDYCdrXg',
#  'ICW90TFdE2U',
#  'fjctYc7xQEU',
#  'flpUszgb4bM',
#  'PqwMEmEuArI',
#  'kB7G9HbI5lo',
#  'cMrpsp5_0FQ',
#  '5DIMLqF1mjU',
#  'qvkNO8Ir9Bk',
#  'yGLx2jO2FK4',
#  '4ivlrKzu38k',
#  'P2dE_CZOfr0',
#  'jo9mv2CutX0',
#  'oG677LEnWLg',
#  'LCFx5sMVcOI',
#  'pgra6jU8e-w',
#  'RWiStfd7pWY',
#  'yJL-W4HdXis',
#  'YEhvODrvicg',
#  'tUeZKO65PIY',
#  'P2eRjbUW53s',
#  'WscHy9Ptqv4',
#  '3Szcsfp06ls',
#  'jsIeoufvkvQ',
#  'Dvve6gFP_8k',
#  'WkkhjzPE_bs',
#  'apiyUVLZwiw',
#  's9S4XbyoNQA',
#  'SwBYn38-j_g',
#  'jtpadu69iZw',
#  '_YIZy69MPn4',
#  '4WRXC4O1-GM',
#  'mkQddzkW4IE',
#  '5ZqHEi6b6Mg',
#  'DouejNCKdYg',
#  'ISW1yeW7Qog',
#  'yBXBpSyCRps',
#  'uGhFQ80lHvM',
#  'QOPqm9LzRRs',
#  'pQXyWZEu6jo',
#  'oKdjfjuStTI',
#  'flZG2SwIH8Q',
#  'fCX0noONtMU',
#  'lUbOIB5nGhE',
#  'mZJuImrtSRY',
#  'iojNe__YMJk',
#  '2cgSR5hhZUs',
#  'yZjQVvf8S8A',
#  'GRj9QaKWUS0',
#  'VFHkM87LiqE',
#  'piKt4bl9MAI',
#  '_-kiyHkN0ug',
#  'lSv_hfESGmc',
#  'ww-hhK9cSRc',
#  'iiCRh_JP9FU',
#  'n8UGDzNmtCc',
#  'JLtHmBLCT8c',
#  'ZMtGxHZWvNM',
#  '6Sx3xAyEyB8',
#  'perz1vQQuB4',
#  'x95jpoxmPPk',
#  'Ky3WXdzUu0U',
#  'oapYCElI2e4',
#  'h65d-RXMsD0',
#  '3eVRo81pqKY',
#  'XtD5qUvvBmk',
#  'XTXHqbdc1Tc',
#  'JuOAwA412Tc',
#  'elPV4BJ2k9o',
#  'QxPozHIZLIs',
#  'kGlKkmAX3LU',
#  '9h-OE8qSVzc',
#  'f2QpF-7f37I',
#  'Fv0AFgb_fKE',
#  'd6PNUAHHLuU',
#  'ZELnvPbX-jM',
#  'MM1EMDjB3sg',
#  '5wEESwBHqWA',
#  'dqj2kzmQsyg',
#  'VQMQIq9weDs',
#  '8KZdoprpjwY',
#  'W0_vWlXepbU',
#  '-NvNPIvvGf0',
#  '4-cgyODq-aY',
#  'zxsGTz4HFfQ',
#  'ylmmg-PUhs4',
#  'sVdLUzAxCOo',
#  'xMODdORUr5c',
#  'cizBME8VBug',
#  'IJvghESl3aM',
#  'F-IPUYG5aUE',
#  'cCUKuj3CuC8',
#  'Parz9QcrbNE',
#  'wc9yHyJNIJE',
#  'xs7PmSZp3Fc',
#  'J3YhRXnI-qI',
#  'rlWBlrFJVcI',
#  'pgsXQ8hG96g',
#  '1gpK5z-PcYA',
#  '3Q5e0X73WEA',
#  'd2BCDvJblJU',
#  '8CI7ZDL_MAA',
#  'fQuGVmJdxNw',
#  'seFRIakVTgM',
#  'Dli7toX2i90',
#  'U6_f19RNobg',
#  'MA_JdReq8ZA',
#  'zbT0z1iV1QA',
#  'DoRk5wd3fDE',
#  'ApCn7zSwgTw',
#  'YEdqo1i4AdE',
#  'CfsDxbtfLg0',
#  'cwUrmJm9O2E',
#  'J4QQ319thJ8',
#  'uIhEnMnzhrA',
#  'I6qBRC_MJCA',
#  '4bWY3-XgBbo',
#  'DGDI8CyEP84',
#  'L18oYTHDoqM',
#  'huG2sRhfHEg',
#  'OzCeDmWx2dk',
#  '17onZhrq1Kg',
#  '2bVGT_8Knwk',
#  'XbRePvJs5EU',
#  '7ycDyLZDAgI',
#  'rityPr84H4M',
#  'rp5ZKUjca8A',
#  'OAitDnieNF4',
#  '-6AUlj7MZe8',
#  'RUICiMluAzs',
#  'EVQ3L8BKK5c',
#  '5eCFoYJJNao',
#  'U310KYHpipY',
#  'TRe17A2hxD4',
#  'C_pvBKnuu0k',
#  'u92knqOyDHE',
#  '5Sdk1t5Kf6A',
#  'oSxITnxJer8',
#  'KWP2v9i07K8',
#  'c4ZMrX3o9vM',
#  '3YBJQxVRq9U',
#  'cnrSA6Ert1g',
#  'N914rFKUfDw',
#  '3GlB05EvBmQ',
#  'DOTHjGzN7w4',
#  '_YmWd1fsOVE',
#  'cC0RvNt0FvY',
#  'iU7nDqOcfEA',
#  '2FoH62SA7Dw',
#  'o_NFpW1KoZg',
#  'pAKtY-uwfp8',
#  'ErJMmm_soZ0',
#  'H26-iE84vxQ',
#  'D0yYcSVWzFM',
#  'OrDHTr4vtfQ',
#  '-EG2astw3cA',
#  'PFpkqZq1em8',
#  '38Tctk8wBUU',
#  '1nQu58VcOFw',
#  'k8BpEyE1kLk',
#  'yUNTcF6I8tE',
#  'f4uyXYQCNdc',
#  'C2JOyYfnJqo',
#  'G1SeRKkLnEA',
#  'd08SixLsUZY',
#  'tYsXmjynJ7k',
#  'sg0hbMJS4Yk',
#  'hhi3Ow2F6zw',
#  'tdV8Zkh31eE',
#  'nOPvg4stxXQ',
#  'aAf2DwTWUjs',
#  '7KkdQh_P8_I',
#  'n-ZRVI0D6Fg',
#  'HLGwEbNoWe0',
#  'hFh0PCMWiHI',
#  'VTIU8z9BfqU',
#  'HRfb2DnFWSE',
#  'XW_W_pCuUHc',
#  '1eFkjdYK1xc',
#  'KGSdzZR-50s',
#  '1T5qkxxT3r0',
#  '8BSz73zEGrQ',
#  'er_F0hcJJRc',
#  'sDP9JirxiiE',
#  'msEw--yRp-I',
#  'hcBpE5sGOsk',
#  'vIUbm8ISL00',
#  'Wi_EsxuD8PQ',
#  '32jcu59CEMg',
#  '5pCOvIAfaQQ',
#  'OgTXiu_dLAI',
#  'mM-WQ2sWT5U',
#  'R6Hn6oWnpzE',
#  '5pCOvIAfaQQ',
#  'f4uyXYQCNdc',
#  'l7jT8cLXKEo',
#  '1eFkjdYK1xc',
#  'KGSdzZR-50s',
#  'AVf642I71T4',
#  'NLIjJsD59UM',
#  'd6dbKI0sfLk',
#  'FHy7n0wUR2E',
#  '1T5qkxxT3r0',
#  'DxJ_jxoptjU',
#  'wawTc35Dqeo',
#  'b6OYymUXG3g',
#  'z4sX1w_AHUk',
#  'LdLbzZ1Nfac',
#  '2PCUTSCfhXo',
#  'h9d69-B6tqI',
#  'm1_NDfdzaOE',
#  'B5elBvTcaCY',
#  'cPHbRsbf3Ls',
#  'RYe3e4TLS8s',
#  'Kt9ynTZoaDA',
#  'pKuEaKtiGrY',
#  '50U9JzvJH5o',
#  'Dn66jS0t7Jo',
#  'tjQ4zlAhvxc',
#  'HNHF-HLVOtg',
#  '6bzGjAVVTqs',
#  'nUX92uIRDVA',
#  '28OeoD0tgSw',
#  'DRMTBjTEJr8',
#  '8BcOnXV_vfA',
#  'FyRU1srvw4g',
#  'unY9WqLpgdk',
#  'qUQiezq6wcU',
#  '3guSfy2qMao',
#  '9fWbZx9Qg1Q',
#  '3tyvfL6eApM',
#  'msLikLU6yQo',
#  'XAjJDc0BfYg',
#  'G-cGNH6CVYA',
#  '_eqH5-dIxBM',
#  'y24GgvCejrg',
#  'vNPFdf6U0p8',
#  'aqu-gbVE6ak',
#  'vRgdm6A7wms',
#  '7_dXx8arTc0',
#  'SClKxNHre88',
#  'XEQJ-zIBBdM',
#  'qTTuvqV2SrU',
#  'MUbyA-aFESI',
#  'vNPFdf6U0p8',
#  'WC37f7VwMi8',
#  '7_dXx8arTc0',
#  'sqiVF4Az74k',
#  'lcHBwFKzVHY',
#  ...]

# %%
# discard live videos
def remove_live_videos(video_ids):
  updated_video_ids = []
  for videoId in video_ids:
    response = youtube.videos().list(
        part='liveStreamingDetails',
        id=videoId
        ).execute()
    try:
      live_streaming_details = response['items'][0]['liveStreamingDetails']
    except:
      updated_video_ids.append(videoId)

  return updated_video_ids

updated_video_ids = remove_live_videos(video_ids)

# %% [markdown]
# Step 3: Fetch video information and transcript

# %%
# YouTubeTranscriptApi
# !pip install youtube_transcript_api
from youtube_transcript_api import YouTubeTranscriptApi
# Out:
# Requirement already satisfied: youtube_transcript_api in /usr/local/lib/python3.10/dist-packages (0.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube_transcript_api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (2024.2.2)

# %%
def get_video_transcript(videoId):
  try:
    transcript = YouTubeTranscriptApi.get_transcript(videoId)
  except:
    transcript = ''

  final_transcript = ''
  if len(transcript) > 10:
    for caption in transcript:
      final_transcript += caption['text']
      final_transcript += ' '

  return final_transcript


def get_video_data(videoId):
  response = youtube.videos().list(
      part='snippet',
      id=videoId
  ).execute()
  title = response['items'][0]['snippet']['title']
  upload_date = response['items'][0]['snippet']['publishedAt']
  upload_date = datetime.datetime.strptime(upload_date, '%Y-%m-%dT%H:%M:%S%z')
  channel = response['items'][0]['snippet']['channelTitle']

  transcript = get_video_transcript(videoId)

  return title, channel, upload_date, transcript

video_list = []
video = {}
for videoId in updated_video_ids:
    title, channel, upload_date, transcript = get_video_data(videoId)
    if transcript == '':
      continue
    video = {'Video ID': videoId, 'Title': title, 'Channel': channel, 'Upload date': upload_date, 'Transcipt': transcript}
    video_list.append(video)

pd.DataFrame(video_list)
# Out:
#          Video ID                                              Title  \
# 0     YEoJq_PcOgc                    What can reignite Apple shares?
# 1     Hp6IRjNJuI4  Jim Cramer on what could be the next $1 trilli...
# 2     GQK4bCZHudM  Top tech stocks don't look 'wildly expensive' ...
# 3     BOm0zNiaNjg             Alphabet's AI problems: Stock falls 4%
# 4     Z0D_FwSF5z0  Jim Cramer talks the 'New Industrial Revolutio...
# ...           ...                                                ...
# 1253  m_gn1XIUNFo  US Supreme Court to hear Donald Trump immunity...
# 1254  RXmMUEGLHEc  Donald Trump can stay on presidential ballot r...
# 1255  S6hF2ffyz2c  Farmers set fires in Brussels ahead of Agricul...
# 1256  pyGyrz06ljg  Israeli protesters block food convoys for star...
# 1257  Wd7voKMwu-c  Dragon Ball creator Akira Toriyama dies aged 6...
#
#               Channel               Upload date  \
# 0     CNBC Television 2024-02-28 17:55:38+00:00
# 1     CNBC Television 2024-02-27 00:23:35+00:00
# 2     CNBC Television 2024-03-06 14:24:00+00:00
# 3     CNBC Television 2024-02-26 19:01:28+00:00
# 4     CNBC Television 2024-03-07 00:38:42+00:00
# ...               ...                       ...
# 1253         BBC News 2024-02-29 09:15:01+00:00
# 1254         BBC News 2024-03-04 15:33:59+00:00
# 1255         BBC News 2024-02-26 11:42:30+00:00
# 1256         BBC News 2024-03-05 23:46:00+00:00
# 1257         BBC News 2024-03-08 17:30:06+00:00
#
#                                               Transcipt
# 0     LATELY. WE ALSO HAVE NEW COMMITTEE MOVES TO DI...
# 1     "MAD MONEY" WITH JIM CRAMER  STARTS RIGHT NOW....
# 2     WE GOT ADT TODAY MIGHT BE INTERESTING, TOO. TH...
# 3     ♪  >>> WELCOME BACK. LET'S TALK ALPHABET. IT I...
# 4     LIKE.  >> "MAD MONEY" WITH JIM CRAMER  STARTS ...
# ...                                                 ...
# 1253  some breaking news because the Supreme Court h...
# 1254  [Music] now we're going to move away from the ...
# 1255  agricultural ministers from across the Europea...
# 1256  President Biden has warned Israel that there a...
# 1257  the creator of Dragon Ball one of the most inf...
#
# [1258 rows x 5 columns]

# %% [markdown]
# Step 4: Identify S&P 500 stocks from video titles

# %%
sp500_df = pd.DataFrame(pd.read_excel('sp500.xlsx'))
sp500_df.drop_duplicates(inplace=True)
sp500_df
# Out:
#              Company Symbol
# 0          Microsoft   MSFT
# 1              Apple   AAPL
# 2             NVIDIA   NVDA
# 3           Alphabet  GOOGL
# 4             Amazon   AMZN
# ..               ...    ...
# 485           Hasbro    HAS
# 486          Generac   GNRC
# 487         Comerica    CMA
# 488  DENTSPLY SIRONA   XRAY
# 489          VF Corp    VFC
#
# [490 rows x 2 columns]

# %%
def identify_stocks_from_titles(title):
  identified_stocks = []
  for i in range(len(sp500_df)):
    company = sp500_df.iloc[i]['Company']
    symbol = sp500_df.iloc[i]['Symbol']

    # check if company in title
    pattern = r'\b{}\b'.format(re.escape(company))
    match = re.search(pattern, title)
    if match:
      identified_stocks.append(i)
    # check if symbol in title given that company is not in title
    else:
      pattern = r'\b{}\b'.format(re.escape(symbol))
      match = re.search(pattern, title)
      if match:
        identified_stocks.append(i)

  return identified_stocks

# %%
for video in video_list:
  identified_stocks = identify_stocks_from_titles(video['Title'])
  video['Stock_indices'] = identified_stocks

# %%
pd.DataFrame(video_list)
# Out:
#          Video ID                                              Title  \
# 0     YEoJq_PcOgc                    What can reignite Apple shares?
# 1     Hp6IRjNJuI4  Jim Cramer on what could be the next $1 trilli...
# 2     GQK4bCZHudM  Top tech stocks don't look 'wildly expensive' ...
# 3     BOm0zNiaNjg             Alphabet's AI problems: Stock falls 4%
# 4     Z0D_FwSF5z0  Jim Cramer talks the 'New Industrial Revolutio...
# ...           ...                                                ...
# 1253  m_gn1XIUNFo  US Supreme Court to hear Donald Trump immunity...
# 1254  RXmMUEGLHEc  Donald Trump can stay on presidential ballot r...
# 1255  S6hF2ffyz2c  Farmers set fires in Brussels ahead of Agricul...
# 1256  pyGyrz06ljg  Israeli protesters block food convoys for star...
# 1257  Wd7voKMwu-c  Dragon Ball creator Akira Toriyama dies aged 6...
#
#               Channel               Upload date  \
# 0     CNBC Television 2024-02-28 17:55:38+00:00
# 1     CNBC Television 2024-02-27 00:23:35+00:00
# 2     CNBC Television 2024-03-06 14:24:00+00:00
# 3     CNBC Television 2024-02-26 19:01:28+00:00
# 4     CNBC Television 2024-03-07 00:38:42+00:00
# ...               ...                       ...
# 1253         BBC News 2024-02-29 09:15:01+00:00
# 1254         BBC News 2024-03-04 15:33:59+00:00
# 1255         BBC News 2024-02-26 11:42:30+00:00
# 1256         BBC News 2024-03-05 23:46:00+00:00
# 1257         BBC News 2024-03-08 17:30:06+00:00
#
#                                               Transcipt Stock_indices
# 0     LATELY. WE ALSO HAVE NEW COMMITTEE MOVES TO DI...           [1]
# 1     "MAD MONEY" WITH JIM CRAMER  STARTS RIGHT NOW....            []
# 2     WE GOT ADT TODAY MIGHT BE INTERESTING, TOO. TH...            []
# 3     ♪  >>> WELCOME BACK. LET'S TALK ALPHABET. IT I...           [3]
# 4     LIKE.  >> "MAD MONEY" WITH JIM CRAMER  STARTS ...            []
# ...                                                 ...           ...
# 1253  some breaking news because the Supreme Court h...            []
# 1254  [Music] now we're going to move away from the ...            []
# 1255  agricultural ministers from across the Europea...            []
# 1256  President Biden has warned Israel that there a...            []
# 1257  the creator of Dragon Ball one of the most inf...            []
#
# [1258 rows x 6 columns]

# %% [markdown]
# Step 5: Save collected data

# %%
pd.DataFrame(video_list).to_csv('youtube_collected_2024.csv')
